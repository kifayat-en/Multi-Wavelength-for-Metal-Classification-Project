# %% [markdown]
# <div style="background-color: teal; padding: 10px 20px; border-radius: 10px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Multi-Wavelength for Metal Classification</span>
# </div>

# %% [markdown]
# <div style="background-color: #f0f8ff; border-left: 6px solid #1e90ff; padding: 15px; border-radius: 10px;">
#     <h3 style="color: #1e90ff">📂 About the Dataset</h3>
#     <p>
#         This dataset is designed for <strong>metal classification</strong> using <em>fluorescence spectroscopy</em>. It contains fluorescence response data for <strong>9 metal ions</strong>: Cr<sup>6+</sup>, Cd<sup>2+</sup>, Co<sup>2+</sup>, Sn<sup>2+</sup>, Al<sup>3+</sup>, Ag<sup>+</sup>, Hg<sup>2+</sup>, Zn<sup>2+</sup>, and Cu<sup>2+</sup>.
#     </p>
#     <p>
#         With <strong>4,500 rows</strong> and <strong>10 columns</strong>, the dataset features <strong>RGB values</strong> recorded at multiple excitation wavelengths and concentrations (10 mM, 8 mM, 6 mM), enabling pattern recognition for each metal.
#     </p>
#     <p>
#         💡 <strong>Applications:</strong> This dataset is ideal for developing <strong>metal classification models using machine learning</strong> and computer vision techniques.
#     </p>
# </div>

# %% [markdown]
# <div style="background-color: teal; padding: 10px 20px; border-radius: 10px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Import Libraries</span>
# </div>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('Clasif_4_10mM_8mM_6mM.xlsx')

# %%
df.head()
# Out:
#   Class        R_10         R_8        R_6        G_10         G_8  \
# 0   Cr6  121.672054  109.359213  90.471411  124.451532  123.095702
# 1   Cr6  121.112364  111.078571  89.707904  125.224216  119.413744
# 2   Cr6  123.482756  110.283060  92.588624  126.517010  119.108594
# 3   Cr6  130.849574  114.185563  90.710288  124.409015  125.553447
# 4   Cr6  125.905786  109.996709  87.328086  125.597695  117.168442
#
#           G_6       B_10        B_8        B_6
# 0  112.594114  17.292427  21.563033  25.679999
# 1  111.906582  14.712391  14.392525  25.054435
# 2  115.020900  15.088266  19.131002  29.599695
# 3  110.210652  18.281800  22.302888  34.465752
# 4  108.006616  19.037181  22.967507  34.676065

# %%
df.shape
# Out:
# (4500, 10)

# %% [markdown]
# <div style="background-color: teal; padding: 10px 20px; border-radius: 10px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Check Null Values</span>
# </div>

# %%
df.isna().sum()
# Out:
# Class    0
# R_10     0
# R_8      0
# R_6      0
# G_10     0
# G_8      0
# G_6      0
# B_10     0
# B_8      0
# B_6      0
# dtype: int64

# %% [markdown]
# <div style="background-color: teal; padding: 10px 20px; border-radius: 10px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Check Duplicates Values</span>
# </div>

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div style="background-color: teal; padding: 10px 20px; border-radius: 10px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Data Summarize, Check Statistical Summary, check correlation</span>
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4500 entries, 0 to 4499
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Class   4500 non-null   object
#  1   R_10    4500 non-null   float64
#  2   R_8     4500 non-null   float64
#  3   R_6     4500 non-null   float64
#  4   G_10    4500 non-null   float64
#  5   G_8     4500 non-null   float64
#  6   G_6     4500 non-null   float64
#  7   B_10    4500 non-null   float64
#  8   B_8     4500 non-null   float64
#  9   B_6     4500 non-null   float64
# dtypes: float64(9), object(1)
# memory usage: 351.7+ KB

# %%
df.describe()
# Out:
#               R_10          R_8          R_6         G_10          G_8  \
# count  4500.000000  4500.000000  4500.000000  4500.000000  4500.000000
# mean     88.332278    77.470631    80.038301   114.324889   105.985361
# std      52.214182    36.770915    38.650804    47.578205    41.880032
# min      24.000701    26.003333    20.023643    26.004921    25.001026
# 25%      44.832874    49.479633    51.630463    89.386239    92.248314
# 50%      71.654329    76.381778    76.798972   117.700998   101.183380
# 75%     128.191895    90.419968    93.437560   158.501880   123.600317
# max     192.953782   160.994446   158.989808   188.988087   176.994449
#
#                G_6         B_10          B_8          B_6
# count  4500.000000  4500.000000  4500.000000  4500.000000
# mean    116.202843   120.988968   122.061103   134.474151
# std      33.457804    58.798000    59.386350    48.883355
# min      55.000100    10.051541     8.004969    25.017636
# ...

# %%
df.corr()
# Out:
#           R_10       R_8       R_6      G_10       G_8       G_6      B_10  \
# R_10  1.000000  0.743122  0.913559  0.595534  0.237102  0.411448 -0.056285
# R_8   0.743122  1.000000  0.869345  0.314475  0.342110  0.253850 -0.143475
# R_6   0.913559  0.869345  1.000000  0.414789  0.189875  0.333819 -0.064571
# G_10  0.595534  0.314475  0.414789  1.000000  0.818532  0.890539  0.483948
# G_8   0.237102  0.342110  0.189875  0.818532  1.000000  0.821479  0.526523
# G_6   0.411448  0.253850  0.333819  0.890539  0.821479  1.000000  0.396811
# B_10 -0.056285 -0.143475 -0.064571  0.483948  0.526523  0.396811  1.000000
# B_8  -0.063962 -0.145374 -0.074865  0.490432  0.542848  0.397323  0.996466
# B_6  -0.104213 -0.276592 -0.118438  0.446127  0.424581  0.422836  0.965470
#
#            B_8       B_6
# R_10 -0.063962 -0.104213
# R_8  -0.145374 -0.276592
# R_6  -0.074865 -0.118438
# G_10  0.490432  0.446127
# G_8   0.542848  0.424581
# G_6   0.397323  0.422836
# B_10  0.996466  0.965470
# ...

# %% [markdown]
# <div style="background-color: teal; padding: 10px 20px; border-radius: 10px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">EDA</span>
#
# </div>

# %% [markdown]
# - Exploratory Data Analysis (Data Visualzation)

# %%
df['Class'].value_counts()
# Out:
# Cr6    500
# Cd2    500
# Co2    500
# Sn2    500
# Al3    500
# Ag     500
# Hg2    500
# Zn2    500
# Cu2    500
# Name: Class, dtype: int64

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(11,6))
sns.scatterplot(x=df['R_10'], y=df['R_6'], hue=df['Class'], s=80, alpha=0.7)
plt.title('ScatterPlot of R-10 VS R-6 With Class', fontsize=16)
plt.xlabel('R 10', fontsize=13)
plt.ylabel('R 6', fontsize=13)

plt.show()

# %%
plt.figure(figsize=(11,6))
sns.scatterplot(x=df['B_10'], y=df['G_8'], hue=df['Class'], s=80, alpha=0.7)
plt.title('ScatterPlot of B-10 VS B-8 With Class', fontsize=16)
plt.xlabel('B 10', fontsize=13)
plt.ylabel('B 8', fontsize=13)

plt.show()

# %%
plt.figure(figsize=(14, 20))
for i, cols in enumerate([ 'R_10', 'R_8', 'R_6', 'G_10', 'G_8', 'G_6', 'B_10', 'B_8','B_6']):
    plt.subplot(5,2, i+1)
    sns.histplot(x=cols, data=df,kde=True, color='orange')
    plt.title(f"Distribution of {cols}")
    plt.tight_layout(pad=4.0)
plt.show()

# %%
plt.figure(figsize=(11,6))
df.boxplot()
plt.title('Check Outliers', fontsize=16)
plt.xlabel('Columns', fontsize=13)
plt.ylabel('Count', fontsize=13)
plt.show()

# %%
plt.figure(figsize=(11,6))
sns.heatmap(df.corr(), annot=True, cmap='YlOrBr')
plt.title('Correlation Metrics of Numerical Cols', fontsize=16)
plt.show()

# %% [markdown]
# <div style="background-color: teal; padding: 10px 20px; border-radius: 10px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Preprocessing</span>
# </div>

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
class_mappings = {}


for col in ['Class']:
    le.fit(df[col].astype('str'))
    
    class_mappings[col] = dict(zip(le.classes_, le.transform(le.classes_) + 1))
    df[col] = le.transform(df[col].astype('str')) + 1 

print("DataFrame updated:")
print(df.head())

print("\nMapping classes:")
for col, mapping in class_mappings.items():
    print(f"{col}: {mapping}")
# Out:
# DataFrame updated:
#    Class        R_10         R_8        R_6        G_10         G_8  \
# 0      3  121.672054  109.359213  90.471411  124.451532  123.095702
# 1      3  121.112364  111.078571  89.707904  125.224216  119.413744
# 2      3  123.482756  110.283060  92.588624  126.517010  119.108594
# 3      3  130.849574  114.185563  90.710288  124.409015  125.553447
# 4      3  125.905786  109.996709  87.328086  125.597695  117.168442
#
#           G_6       B_10        B_8        B_6
# 0  112.594114  17.292427  21.563033  25.679999
# 1  111.906582  14.712391  14.392525  25.054435
# 2  115.020900  15.088266  19.131002  29.599695
# 3  110.210652  18.281800  22.302888  34.465752
# 4  108.006616  19.037181  22.967507  34.676065
#
# Mapping classes:
# Class: {'2.0': 1, '3.0': 2, '6.0': 3, 'nan': 4}

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix, f1_score, recall_score

# %%
X = df.drop('Class', axis=1)
y = df['Class']

X_train,X_test, y_train,y_test = train_test_split(X,y , test_size=0.3)
print(f"X_train Shape: {X_train.shape}")
print(f"Y_train Shape: {y_train.shape}")
print(f"X_test Shape: {X_test.shape}")
print(f"y_test Shape: {y_test.shape}")
# Out:
# X_train Shape: (3150, 9)
# Y_train Shape: (3150,)
# X_test Shape: (1350, 9)
# y_test Shape: (1350,)

# %% [markdown]
# <div style="background-color: teal; padding: 10px 20px; border-radius: 10px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">ML Models</span>
# </div>

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "SVM": SVC(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    'KNeighbors Classifier': KNeighborsClassifier(),
    "Decision Tree": DecisionTreeClassifier()
}

# %%
data = []
for model_names, model in models.items():
    model.fit(X_train, y_train)
    preds = model.predict(X_test)
    score = accuracy_score(y_test, preds)
    prec = precision_score(y_test, preds, average='macro')
    recal = recall_score(y_test, preds, average='macro')
    f1 = f1_score(y_test, preds,  average='macro')
    print(f"\nName: {model_names}")
    print(f"Accuracy: {score:.2f}")
    print(f"Precision Score: {prec}")
    
    plt.figure(figsize=(6, 4))
    cm  = confusion_matrix(y_test,preds)
    sns.heatmap(cm, annot=True, cmap='YlOrBr')
    plt.title(f"{model_names}- Confution Metrics")
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.tight_layout()
    plt.show()
    
    data.append({
        'Model': model_names,
        'Test Accuracy': score, 
        'Precision Score': prec,
        'Recall Score': recal,
        'F1 Score': f1
        
    })
    summary_df = pd.DataFrame(data)

# Show all model evaluation metrics in one table
print("\nSummary:")
summary_df
# Out:
# Name: Logistic Regression
# Accuracy: 1.00
# Precision Score: 1.0
# Name: Random Forest
# Accuracy: 1.00
# Precision Score: 1.0
# Name: Gradient Boosting
# Accuracy: 1.00
# Precision Score: 1.0
# Name: SVM
# Accuracy: 1.00
# Precision Score: 1.0
# Name: K-Nearest Neighbors
# Accuracy: 1.00
# Precision Score: 1.0
# Name: Naive Bayes
# Accuracy: 1.00
# Precision Score: 1.0
# Name: KNeighbors Classifier
# Accuracy: 1.00
# Precision Score: 1.0
# Name: Decision Tree
# Accuracy: 1.00
# Precision Score: 1.0
# Summary:
#                    Model  Test Accuracy  Precision Score  Recall Score  \
# 0    Logistic Regression            1.0              1.0           1.0
# 1          Random Forest            1.0              1.0           1.0
# 2      Gradient Boosting            1.0              1.0           1.0
# 3                    SVM            1.0              1.0           1.0
# 4    K-Nearest Neighbors            1.0              1.0           1.0
# ...

# %% [markdown]
# <div style="background-color: teal; padding: 10px 20px; border-radius: 10px; display: flex; justify-content: center; align-items: center; height: 40px;">
#     <span style="color: white; font-size: 18px; font-weight: bold;">Summary</span>
# </div>

# %%
plt.figure(figsize=(12, 5))
sns.barplot(data=summary_df, x='Model', y='Test Accuracy', palette='YlOrBr')
plt.title("Model Accuracy Comparison")
plt.xlabel('Model Name')
plt.ylabel("Accuracy")
plt.grid()
plt.xticks(rotation=45)
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# <div style="background-color: #f0f8ff; border-left: 6px solid #1e90ff; padding: 15px; border-radius: 10px;">
#     <h3 style="color: #1e90ff">Summary</h3>
#     <p>
#         💡ll machine learning models achieved perfect accuracy in classifying metals using fluorescence data.
#     This indicates strong feature separability and the effectiveness of spectral responses for classification.
#     The dataset is highly reliable for building accurate and efficient metal detection systems.
#     </p>
# </div>
